# %% [markdown]
# - lets bring the Loan default balanced data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:\\ML PROJECT\\loan_default_prediction\\data\\raw\\Loan_default_balanced.csv")

# %%
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  53JZI72VZV   24   60731      168109          356              59
# 1  XYWAVPQ2DD   50  120733       29562          383               7
# 2  ZNPPW580OQ   37   79440      228793          598              99
# 3  CU72EQKSQ0   25   78531       59639          578               0
# 4  P6ZZXZ589N   18   96487      183305          394              79
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio   Education  \
# 0               2         10.80        60      0.81    Master's
# 1               4         19.72        12      0.71    Master's
# 2               3         13.50        36      0.27  Bachelor's
# 3               1         23.55        60      0.50  Bachelor's
# 4               1         16.69        48      0.31    Master's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Part-time      Divorced         Yes            No        Home
# ...

# %%
df["Default"].value_counts()
# Out:
# Default
# 0    29653
# 1    29653
# Name: count, dtype: int64

# %% [markdown]
# ## 🌳 Random Forest Feature Importance
#
# ### 💡 What is Feature Importance?
#
# Feature Importance tells us which features are most useful when predicting the target variable. Random Forest automatically measures the importance of each feature during training.
#
# ---
#
# ### 🧠 How Random Forest Calculates Feature Importance:
#
# 1. **Mean Decrease in Impurity (MDI):**
#    - During the tree-building process, each feature is used to split the data.
#    - Each split reduces a measure of impurity (like Gini impurity or entropy).
#    - Features that result in large impurity reduction across many trees are ranked higher.
#
# 2. **Mean Decrease Accuracy (MDA) [Permutation Importance]:**
#    - After the model is trained, the values of each feature are randomly shuffled.
#    - The drop in accuracy shows how important the feature was.
#    - A bigger drop means the feature was more important.
#
# ---
#
# ### 🔥 Why Use Feature Importance?
#
# - 🏆 **Feature Selection:**
#   Identify and keep only relevant features to avoid overfitting.
#
# - ⚡️ **Model Interpretation:**
#   Understand which variables affect the prediction most.
#
# - 💡 **Business Insight:**
#   Helps explain to stakeholders which features drive decision-making.

# %%
# from sklearn.ensemble import RandomForestClassifier
# import matplotlib.pyplot as plt
# import seaborn as sns


# # sliting the data with features and Target 


# X = df.drop(['LoanID','Default'] , axis=1)  # features
# y = df['Default']  # target 


# # model creation RandomForest

# rf = RandomForestClassifier (n_estimators =100, random_state=42)


# # fit model
# rf.fit(X,y)

# #Extract Feature importance 
# importances = rf.feature_importances_
# feature_names = X.columns

# # Create data frame for visualization 
# feature_importance_df = pd.DataFrame(

#    { 'Feature' : feature_names,
#     'Importance' : importances
#     }
# ).sort_values(by='Importance', ascending=False)

# #plot 
# plt.figure(figsize=(10.7))
# sns.barplot(x='importance' , y= 'Feature', data = feature_importance_df, palette ='viridis')
# plt.title('Feature Importance using Random Forest')
# plt.tight_layout()
# plt.show()
